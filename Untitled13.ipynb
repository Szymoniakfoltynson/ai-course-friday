# %% [markdown]
# <a href="https://colab.research.google.com/github/Szymoniakfoltynson/ai-course-friday/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

with open("tagi_gier_wspoldzielone.json", encoding="utf-8") as f:
    data = json.load(f)

tag_count = {}
tag_to_labels = {}


print(len(data))
print(len(label_count))
for label in label_count:
  print(label, label_count[label])
# Out:
# 300
# 0

# %%
tag_count = {}
tag_to_labels = {}

for game in data:
    label = game["label"]
    for tag in game["tags"]:
        if tag not in tag_count:
            tag_count[tag] = 0
        tag_count[tag] += 1

        if tag not in tag_to_labels:
            tag_to_labels[tag] = []
        if label not in tag_to_labels[tag]:
            tag_to_labels[tag].append(label)

only_one = 0
multiple_labels = 0
for tag in tag_to_labels:
    label_total = len(tag_to_labels[tag])
    if label_total == 1:
        only_one += 1
    else:
        multiple_labels += 1

print("Liczba tagów:", len(tag_count))
print("Tagi przypisane tylko do jednej gry:", only_one)
print("Tagi wspólne dla wielu gier:", multiple_labels)

# 4. Wyświetl 20 najczęściej występujących tagów wraz z liczbą wystąpień
print("\n20 najczęstszych tagów:")
sorted_tags = sorted(tag_count.items(), key=lambda x: x[1])
for tag, count in sorted_tags[-20:]:
    print(" -", tag, ":", count, "razy")
# Out:
# Liczba tagów: 74
# Tagi przypisane tylko do jednej gry: 25
# Tagi wspólne dla wielu gier: 49
#
# 20 najczęstszych tagów:
#  - przetrwanie : 38 razy
#  - sklep : 38 razy
#  - questy : 39 razy
#  - fortyfikacje : 39 razy
#  - symulator : 39 razy
#  - aktualizacja : 39 razy
#  - pistolet : 40 razy
#  - waluta : 40 razy
#  - karabin : 41 razy
#  - arena : 41 razy
#  - kopanie : 43 razy
#  - oddziały : 43 razy
#  - loot : 44 razy
#  - rankedy : 44 razy
#  - klocki : 46 razy
#  - sezon : 46 razy
#  - emotki : 46 razy
#  - budowanie : 48 razy
#  - crafting : 49 razy
#  - roleplay : 50 razy

# %%
import random, math

def load_data(path):
    """Zwraca listę słowników {label: ..., tags: [...] }"""
    with open(path, encoding="utf‑8") as f:
        return json.load(f)

def train_test_split(data, test_ratio=0.2):
  random.shuffle(data)
  cut = int(len(data) * test_ratio)
  return data[cut:], data[0:cut]

def evaluate(model, test):
  correct = 0
  for x in test:
    if predict(model, x) == x["label"]:
      correct += 1
  print("Accuracy = ", correct / len(test))

# %%
def build_vocabulary(train):
    vocab = set()
    for rec in train:
        vocab.update(rec["tags"])
    print (vocab)
    return vocab

#Trenowanie modelu klasyfikatora Bayesa
def train_nb(train, vocab, alpha=1.0):
    class_counts = {}
    word_counts  = {}
    total_words  = {}

    for rec in train:
        c = rec["label"]
        class_counts[c]  = class_counts.get(c, 0) + 1
        word_counts.setdefault(c, {})
        total_words.setdefault(c, 0)

        for tag in rec["tags"]:
            word_counts[c][tag] = word_counts[c].get(tag, 0) + 1
            total_words[c]     += 1

    model = {
        "class_counts": class_counts,
        "word_counts":  word_counts,
        "total_words":  total_words,
        "vocab":        vocab,
        "alpha":        alpha,
        "total_docs":   len(train)
    }
    print(model)
    return model

# Obliczanie log‑prawdopodobieństwa jednej klasy dla rekordu
def log_prob(model, rec, class_name):
    logp = math.log(model["class_counts"][class_name] / model["total_docs"])
    V    = len(model["vocab"])
    a    = model["alpha"]


    for tag in rec["tags"]:
        wc = model["word_counts"][class_name].get(tag, 0)
        logp += math.log((wc + a) / (model["total_words"][class_name] + a * V))
    return logp

#Predykcja – wybieramy klasę z najwyższym log‑prawdop.
def predict(model, rec):
    best_class, best_log = None, -1e99
    for c in model["class_counts"]:
        lp = log_prob(model, rec, c)
        if lp > best_log:
            best_class, best_log = c, lp
    return best_class

# %%
data = load_data("tagi_gier_wspoldzielone.json")
train, test = train_test_split(data)
vocab =  build_vocabulary(train)
model = train_nb(train, vocab)
evaluate(model, test)
# Out:
# {'lua', 'wydarzenia', 'crafting', 'studio', 'burza', 'czat', 'oddziały', 'roleplay', 'lama', 'online', 'runy', 'obby', 'fortyfikacje', 'sandbox', 'drużyna', 'skiny', 'nether', 'parkour', 'survival', 'budowanie', 'arena', 'awp', 'sklep', 'aktualizacja', 'questy', 'sezon', 'przetrwanie', 'autobus bojowy', 'brokhaven', 'misje', 'tickrate', 'multiplayer', 'waluta', 'nexus', 'zombie', 'esport', 'creepery', 'dust2', 'tryb', 'kolekcje', 'rankingi', 'flash', 'baron', 'wyzwania', 'karabin', 'bomba', 'duety', 'ulti', 'snajper', 'tryb kreatywny', 'klocki', 'redstone', 'bohaterowie', 'robuxy', 'kopanie', 'hardcore', 'event', 'symulator', 'battle', 'smok', 'v-bucksy', 'mapa', 'emotki', 'diamenty', 'biomy', 'strzał w głowę', 'dżungla', 'slurp', 'tryb solo', 'loot', 'prywatny serwer', 'pistolet', 'strzelanie', 'rankedy'}
# {'class_counts': {'minecraft': 51, 'roblox': 53, 'cs': 47, 'lol': 45, 'fortnite': 44}, 'word_counts': {'minecraft': {'pistolet': 7, 'czat': 2, 'karabin': 9, 'event': 6, 'smok': 20, 'creepery': 23, 'online': 4, 'symulator': 9, 'parkour': 4, 'duety': 6, 'tryb kreatywny': 9, 'fortyfikacje': 10, 'rankingi': 9, 'biomy': 5, 'redstone': 21, 'roleplay': 7, 'kolekcje': 7, 'prywatny serwer': 4, 'wydarzenia': 3, 'diamenty': 22, 'sezon': 8, 'hardcore': 3, 'waluta': 6, 'loot': 6, 'survival': 4, 'skiny': 8, 'tryb solo': 7, 'arena': 8, 'przetrwanie': 7, 'drużyna': 3, 'emotki': 7, 'bohaterowie': 9, 'zombie': 8, 'rankedy': 7, 'aktualizacja': 7, 'sklep': 6, 'wyzwania': 7, 'strzelanie': 4, 'battle': 6, 'nether': 16, 'budowanie': 7, 'mapa': 7, 'snajper': 7, 'esport': 8, 'crafting': 12, 'tryb': 3, 'klocki': 9, 'questy': 8, 'sandbox': 8, 'kopanie': 3, 'strzał w głowę': 5, 'oddziały': 3, 'multiplayer': 2, 'misje': 2}, 'roblox': {'lua': 27, 'wydarzenia': 6, 'tryb solo': 4, 'robuxy': 23, 'strzelanie': 9, 'kopanie': 6, 'arena': 7, 'oddziały': 11, 'parkour': 10, 'obby': 15, 'budowanie': 7, 'fortyfikacje': 4, 'emotki': 14, 'wyzwania': 6, 'strzał w głowę': 8, 'crafting': 7, 'klocki': 6, 'symulator': 5, 'waluta': 9, 'questy': 7, 'studio': 19, 'pistolet': 8, 'aktualizacja': 5, 'rankingi': 9, 'roleplay': 6, 'sezon': 8, 'prywatny serwer': 9, 'survival': 7, 'brokhaven': 22, 'duety': 5, 'karabin': 8, 'mapa': 3, 'misje': 5, 'sklep': 4, 'drużyna': 4, 'sandbox': 9, 'kolekcje': 3, 'hardcore': 6, 'battle': 4, 'czat': 6, 'snajper': 6, 'bohaterowie': 5, 'event': 3, 'esport': 6, 'biomy': 9, 'loot': 13, 'tryb': 5, 'tryb kreatywny': 6, 'online': 4, 'przetrwanie': 5, 'rankedy': 6, 'multiplayer': 5, 'skiny': 6, 'zombie': 4}, 'cs': {'fortyfikacje': 6, 'bomba': 17, 'awp': 18, 'roleplay': 11, 'parkour': 6, 'drużyna': 6, 'aktualizacja': 11, 'mapa': 5, 'tryb solo': 8, 'battle': 3, 'hardcore': 7, 'dust2': 16, 'multiplayer': 4, 'emotki': 7, 'oddziały': 10, 'tickrate': 18, 'survival': 5, 'symulator': 7, 'klocki': 11, 'loot': 7, 'waluta': 7, 'flash': 25, 'questy': 7, 'budowanie': 9, 'kopanie': 8, 'arena': 6, 'sezon': 7, 'przetrwanie': 7, 'sklep': 6, 'strzał w głowę': 6, 'rankedy': 8, 'online': 4, 'event': 7, 'rankingi': 2, 'pistolet': 5, 'bohaterowie': 8, 'czat': 6, 'misje': 4, 'crafting': 7, 'karabin': 6, 'duety': 3, 'strzelanie': 2, 'wydarzenia': 5, 'kolekcje': 5, 'snajper': 5, 'tryb': 5, 'sandbox': 3, 'zombie': 5, 'prywatny serwer': 4, 'tryb kreatywny': 1, 'skiny': 5, 'wyzwania': 2, 'biomy': 3}, 'lol': {'nexus': 22, 'esport': 9, 'tryb': 4, 'drużyna': 2, 'mapa': 7, 'symulator': 4, 'oddziały': 6, 'ulti': 20, 'arena': 8, 'kopanie': 8, 'budowanie': 8, 'sklep': 8, 'baron': 21, 'sezon': 7, 'aktualizacja': 5, 'tryb solo': 6, 'przetrwanie': 9, 'hardcore': 6, 'roleplay': 11, 'klocki': 6, 'battle': 3, 'karabin': 3, 'dżungla': 13, 'waluta': 6, 'parkour': 3, 'questy': 9, 'runy': 14, 'pistolet': 5, 'loot': 7, 'bohaterowie': 3, 'kolekcje': 5, 'rankedy': 5, 'wydarzenia': 6, 'sandbox': 3, 'strzał w głowę': 5, 'snajper': 8, 'zombie': 4, 'skiny': 4, 'biomy': 5, 'online': 4, 'misje': 5, 'tryb kreatywny': 10, 'rankingi': 3, 'fortyfikacje': 4, 'czat': 7, 'duety': 7, 'event': 5, 'survival': 5, 'multiplayer': 4, 'crafting': 5, 'strzelanie': 3, 'wyzwania': 5, 'prywatny serwer': 3, 'emotki': 2}, 'fortnite': {'kolekcje': 9, 'karabin': 10, 'autobus bojowy': 15, 'biomy': 2, 'lama': 17, 'strzelanie': 4, 'loot': 5, 'symulator': 4, 'aktualizacja': 6, 'wydarzenia': 5, 'przetrwanie': 6, 'mapa': 7, 'drużyna': 3, 'snajper': 5, 'rankingi': 8, 'hardcore': 5, 'tryb': 4, 'v-bucksy': 18, 'klocki': 9, 'emotki': 6, 'czat': 5, 'duety': 5, 'crafting': 7, 'rankedy': 12, 'burza': 21, 'parkour': 4, 'bohaterowie': 4, 'slurp': 17, 'pistolet': 2, 'budowanie': 12, 'sklep': 5, 'esport': 5, 'tryb solo': 4, 'roleplay': 9, 'arena': 5, 'sezon': 6, 'questy': 3, 'survival': 5, 'zombie': 5, 'waluta': 5, 'multiplayer': 6, 'sandbox': 5, 'skiny': 7, 'oddziały': 3, 'online': 5, 'fortyfikacje': 6, 'event': 4, 'prywatny serwer': 4, 'wyzwania' ...
# Accuracy =  1.0
